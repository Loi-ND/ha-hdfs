# %%
from pyspark.sql import SparkSession

def main():
    spark = (
        SparkSession.builder
        .appName("PySpark-Cluster-Test")
        # nếu bạn chạy trên YARN cluster
        .master("yarn")
        .getOrCreate()
    )

    sc = spark.sparkContext

    print("=== Spark Info ===")
    print("App name:", sc.appName)
    print("Master:", sc.master)
    print("Spark version:", sc.version)

    # Tạo dữ liệu trong memory
    data = list(range(1, 101))

    rdd = sc.parallelize(data, numSlices=4)

    # Một số phép toán đơn giản
    result = (
        rdd
        .map(lambda x: x * x)
        .filter(lambda x: x % 2 == 0)
        .sum()
    )

    print("Result:", result)

    spark.stop()

if __name__ == "__main__":
    main()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/06 04:48:38 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/02/06 04:48:39 WARN Client: Neither spark.yarn.jars nor spark.yarn.archive is set, falling back to uploading libraries under SPARK_HOME.
# === Spark Info ===
# App name: PySpark-Cluster-Test
# Master: yarn
# Spark version: 3.5.8
# Result: 171700
